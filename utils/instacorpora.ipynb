# %%
import nltk
nltk.download('wordnet')
nltk.download('omw-1.4')
from nltk.corpus import wordnet as wn

# %%
from collections import Counter
from itertools import chain
from deep_translator import GoogleTranslator
from ftlangdetect import detect
import re
import random

# %% [markdown]
# Считывание корпуса хэштегов

# %%
with open(r"C:full_tag_list.txt", "r", encoding="utf-8") as file:
    hashtags = file.readlines()

# %%
hashtags_all=[]
for st in hashtags:
    hashtags_all.append(st.strip().split())

# %% [markdown]
# ### Обработка

# %%
# определение языка
def get_lang(string_obj):
    result = detect(text=string_obj, low_memory=False)
    return result['lang']

# %%
# Отбрасываем хэштеги, если гиперонимы из списка
banned_hypernyms = ['emotion','feeling', 'quality', 'temperature']

# %%
def get_hypernyms(word, stop_hyp):
    current_hypernyms = ''
    flag_stop_word = False
    flag_empty = False
    first_meaning = ''
    for i,j in enumerate(wn.synsets(word)):
        if i == 0:
            first_meaning = j.name().split('.')[0]
        current_hypernyms += ', ' + ", ".join(list(chain(*[l.lemma_names() for l in j.hypernyms()])))
    for w in stop_hyp:
        if w in current_hypernyms:
            flag_stop_word = True
    if current_hypernyms == '':
        flag_empty = True
    return first_meaning, flag_stop_word, flag_empty

# %%
data_remade = []
for row in hashtags_all:
    row_remade = []
    for tag in row:
        # автоматическая чистка основаных мусорных хэштегов
        if tag in ['instagram', 'instapic', 'instagrammers', 'instagramers', 'instagramhub']:
            tag = ''
        elif 'like' in tag:
            tag = ''
        elif 'ofinstagram' in tag:
            tag = re.sub(r'ofinstagram', '', tag)
        elif 'instagram' in tag:
            tag = re.sub(r'instagram', '', tag)
        elif 'insta' in tag:
            tag = re.sub(r'insta', '', tag)
        
        if tag != '':
            lang = get_lang(tag)
            if lang != 'en':
                try:
                    # перевод иноязычных хэштегов, только после FastText модели!
                    tag = GoogleTranslator(source=lang, target='en').translate(tag)
                except:
                    tag = GoogleTranslator(source='auto', target='en').translate(tag)
            _, flag_stop_word, _ = get_hypernyms(tag, banned_hypernyms)
            if flag_stop_word == True:
                tag = ''

        if tag != '':
            row_remade.append(tag)
            
    data_remade.append(row_remade)

# %% [markdown]
# Дополнение последовательностей хэштегами из того же кластера
#
# - Векторизация FastText
# - Кластеризация DBSCAN

# %%
import fasttext
from sklearn.cluster import DBSCAN
import sklearn
import numpy as np

# %%
with open('hashtags_dataset.txt', 'r', encoding='utf-8') as file:
    checked_hashtags = file.readlines()

# %%
new_hashtags=[]
for st in checked_hashtags:
    new_hashtags.append(list(set(st.strip().split())))

# %%
ft_model = fasttext.load_model(r"wiki.en.bin")
# Out:
# Warning : `load_model` does not return WordVectorModel or SupervisedModel any more, but a `FastText` object which is very similar.

# %%
dict_keys = []
dict_vals = []
for row in new_hashtags:
    for obj in row:
        if obj not in dict_keys:
            dict_keys.append(obj)
            dict_vals.append(ft_model[obj])

# %%
X_data = np.array(dict_vals)

# %%
clustering = DBSCAN(eps=0.3826, min_samples=3, metric='cosine').fit(X_data)

# %%
len(set(clustering.labels_))
# Out:
# 39

# %%
clusters = {}
for cl in list(set(clustering.labels_)):
    if cl not in clusters:
        clusters[cl] = []

for i in range(len(dict_keys)):
    clusters[clustering.labels_[i]].append(dict_keys[i])

# %%
clusters[34]
# Out:
# ['nailsonfleek', 'nailsta', 'nailsart', 'nailsalon']

# %%
agglo  = sklearn.cluster.FeatureAgglomeration(n_clusters=60, metric='cosine', linkage='average')
agglo.fit(X_data.T)
# Out:
# FeatureAgglomeration(linkage='average', metric='cosine', n_clusters=60)

# %%
agglo_clusters = {}
for cl in list(set(agglo.labels_)):
    if cl not in agglo_clusters:
        agglo_clusters[cl] = []

# %%
for i in range(len(dict_keys)):
    agglo_clusters[agglo.labels_[i]].append(dict_keys[i])

# %%
agglo_clusters[45]
# Out:
# ['urban', 'city', 'tourist', 'hub', 'tourism']

# %%
groups = clusters

# %%
additional_data = []

for row in new_hashtags:
    random.shuffle(groups)
    new_row = row
    addition = []
    if len(row) < 6:
        for var in groups:
            if len(set(row) & set(var)) > 0:
                temp_diff = list(set(var) - set(row))
                if len(temp_diff) == 0:
                    continue
                else:
                    num = random.randint(1, len(temp_diff))
                    addition = random.sample(temp_diff, num)
                    print(row)
                    print('>>>', addition)
                    break
    new_row += addition
    additional_data.append(new_row)
# Out:
# ['travel', 'sea', 'trip', 'wanderlust', 'vacation']
# >>> ['travelphotography', 'adventure', 'travelblogger']
# ['travel', 'sea', 'traveling', 'travelblogger', 'wanderlust']
# >>> ['travelphotography', 'adventure']
# ['travel', 'sea', 'travelphotography', 'wanderlust', 'adventure']
# >>> ['travelblogger', 'vacation']
# ['sea', 'art', 'artistzone', 'painting', 'color']
# >>> ['colors', 'artwork', 'drawing', 'creative']
# ['travel', 'sea', 'travelblogger', 'wanderlust']
# >>> ['vacation']
# ['travel', 'sea', 'travelphotography', 'travelblogger', 'vacation']
# >>> ['wanderlust']
# ['travel', 'sea', 'adventure', 'travelblogger', 'travelphotography']
# >>> ['vacation', 'wanderlust']
# ['style', 'home', 'interior', 'streetstyle', 'styleblogger']
# >>> ['outfitoftheday', 'outfit']
# ['inspiration', 'home', 'quotes', 'goodvibes', 'selflove']
# >>> ['quote']
# ['home', 'lifeisgood', 'adventure', 'travelblogger', 'travel']
# >>> ['wanderlust', 'travelphotography']
# ['home', 'pet', 'cutepetclub', 'cuteanimals', 'cutepet']
# >>> ['petsofourworld', 'animaladdicts', 'cutenessoverload', 'animal', 'animals']
# ['couple', 'yummy', 'instafood', 'foodlover', 'foodphotography']
# >>> ['food', 'foodporn', 'tasty', 'delicious', 'bonappetit']
# ['style', 'amazing', 'fashionista', 'fashionblogger', 'fashion']
# >>> ['outfit', 'styleblogger', 'outfitoftheday', 'streetstyle']
# ['streetstyle', 'outfit', 'style']
# >>> ['fashionblogger', 'outfitoftheday', 'fashion']
# ['funny', 'pet', 'cutepetclub', 'animaladdicts', 'cutenessoverload']
# >>> ['pets']
# ['travel', 'comedy', 'wanderlust', 'travelblogger', 'vacation']
# >>> ['travelphotography', 'adventure']
# ['style', 'styleblogger', 'fashion', 'streetstyle', 'outfitoftheday']
# >>> ['fashionblogger', 'outfit', 'fashionista']
# ['style', 'photooftheday', 'fashionista', 'streetstyle']
# >>> ['fashion', 'fashionblogger']
# ['pet', 'cutenessoverload', 'pets', 'petsofourworld', 'animals']
# >>> ['cuteanimals', 'cutepetclub']
# ['pet', 'pets', 'animal', 'cutepetclub']
# >>> ['animals', 'animaladdicts', 'cutenessoverload', 'petsofourworld']
# ['pet', 'animals', 'pets']
# >>> ['cutepet', 'cuteanimals']
# ['pet', 'pets', 'animaladdicts', 'cuteanimals']
# >>> ['cutepetclub']
# ['pet', 'animal', 'cuteanimals', 'petsofourworld']
# >>> ['pets', 'animals', 'cutenessoverload', 'cutepet', 'animaladdicts']
# ['pet', 'face', 'animal', 'cutepet', 'animaladdicts']
# >>> ['petsofourworld', 'cutepetclub', 'animals', 'cuteanimals']
# ['pet', 'pets', 'animal', 'animals']
# >>> ['petsofourworld', 'cuteanimals', 'cutepetclub', 'cutepet', 'animaladdicts', 'cutenessoverload']
# ['pet', 'pets', 'cuteanimals', 'animals', 'cutepet']
# >>> ['cutepetclub', 'animal', 'cutenessoverload', 'animaladdicts', 'petsofourworld']
# ['photooftheday', 'pet', 'cutepet', 'cutenessoverload', 'petsofourworld']
# >>> ['cutepetclub', 'pets']
# ['black', 'pet', 'animals', 'animal']
# >>> ['cuteanimals', 'cutepet']
# ['pet', 'cutepet', 'petsofourworld', 'animaladdicts', 'animal']
# >>> ['cuteanimals', 'animals', 'pets', 'cutepetclub']
# ['pet', 'cuteanimals', 'animal', 'cutepetclub']
# >>> ['petsofourworld', 'cutepet', 'animals']
# ['pet', 'petsofourworld', 'cuteanimals', 'pets', 'cutepet']
# >>> ['animals', 'cutenessoverload']
# ['pet', 'cuteanimals', 'animal', 'pets', 'animals']
# >>> ['cutepetclub']
# ['play', 'pet', 'petsofourworld', 'animal', 'pets']
# >>> ['cutepet', 'animaladdicts', 'cuteanimals']
# ['cute', 'pet', 'petsofourworld', 'cutepet']
# >>> ['cutenessoverload', 'cuteanimals', 'pets', 'animals', 'animal', 'cutepetclub']
# ['pet', 'cutepet', 'petsofourworld', 'cuteanimals', 'pets']
# >>> ['animals', 'cutepetclub', 'animal']
# ['black', 'pet', 'petsofourworld', 'animals', 'cuteanimals']
# >>> ['pets', 'animaladdicts', 'cutepetclub', 'animal']
# ['pet', 'animal', 'animals', 'petsofourworld', 'cuteanimals']
# >>> ['animaladdicts', 'pets', 'cutepetclub', 'cutepet', 'cutenessoverload']
# ['pet', 'cutenessoverload', 'animals', 'pets', 'animal']
# >>> ['petsofourworld', 'cuteanimals', 'animaladdicts', 'cutepetclub']
# ['pet', 'cutepet', 'pets']
# >>> ['animal', 'petsofourworld', 'animals', 'cutenessoverload', 'animaladdicts', 'cuteanimals', 'cutepetclub']
# ['amazing', 'pet', 'pets', 'cutepet', 'petsofourworld']
# >>> ['cuteanimals', 'animals']
# ['cute', 'pet', 'cutepetclub', 'cutepet', 'pets']
# >>> ['cuteanimals', 'cutenessoverload', 'animaladdicts', 'animals']
# ['pet', 'cutepetclub', 'petsofourworld', 'animal', 'cuteanimals']
# >>> ['pets', 'cutenessoverload', 'animaladdicts', 'animals']
# ['pet', 'petsofourworld', 'animal', 'cuteanimals']
# >>> ['cutenessoverload', 'pets']
# ['pet', 'animaladdicts', 'pets', 'cuteanimals', 'animal']
# >>> ['petsofourworld', 'cutepetclub', 'animals', 'cutenessoverload']
# ['pet', 'cutepetclub', 'animals', 'cuteanimals', 'animaladdicts']
# >>> ['cutenessoverload', 'animal']
# ['pet', 'cuteanimals', 'cutenessoverload', 'cutepet', 'animaladdicts']
# >>> ['petsofourworld']
# ['pet', 'animaladdicts', 'cutenessoverload', 'cutepet', 'petsofourworld']
# >>> ['animal', 'animals']
# ['pet', 'cuteanimals', 'cutenessoverload', 'animaladdicts']
# >>> ['cutepetclub', 'cutepet', 'animal']
# ['pet', 'cutenessoverload', 'petsofourworld', 'animal', 'cuteanimals']
# >>> ['animaladdicts', 'animals']
# ['quote', 'friend', 'inspiration', 'quotes', 'selflove']
# >>> ['goodvibes']
# ['landscape', 'travel', 'weekend', 'travelphotography', 'wanderlust']
# >>> ['adventure']
# ['hardweek', 'quote', 'inspiration', 'goodvibes', 'goals']
# >>> ['selflove']
# ['travel', 'white', 'travelblogger', 'travelphotography', 'vacation']
# >>> ['adventure', 'wanderlust']
# ['fashion', 'white', 'outfit', 'outfitoftheday']
# >>> ['fashionblogger', 'styleblogger']
# ['yum', 'weightloss', 'healthy', 'nutrition', 'wellness']
# >>> ['healthylifestyle']
# ['yum', 'healthy', 'nutrition', 'wellness', 'healthylifestyle']
# >>> ['health']
# ['yum', 'vacation', 'adventure', 'travelphotography']
# >>> ['wanderlust', 'travel']
# ['red', 'drawing', 'colors', 'artistzone']
# >>> ['art', 'creative']
# ['red', 'art', 'artistzone', 'creative', 'artwork']
# >>> ['painting']
# ['red', 'fashionista', 'fashionblogger', 'styleblogger', 'style']
# >>> ['outfitoftheday', 'outfit', 'streetstyle']
# ['sportswear', 'sleep', 'pet', 'petsofourworld', 'cuteanimals']
# >>> ['cutepetclub', 'pets', 'animaladdicts']
# ['fashion', 'sportswear', 'fashionblogger', 'styleblogger', 'streetstyle']
# >>> ['fashionista']
# ['style', 'sportswear', 'shoe', 'fashionblogger', 'fashion']
# >>> ['styleblogger', 'streetstyle']
# ['style', 'fashion', 'outfit', 'styleblogger', 'outfitoftheday']
# >>> ['streetstyle', 'fashionblogger', 'fashionista']
# ['style', 'sportswear', 'styleblogger', 'fashion']
# >>> ['outfit', 'fashionista']
# ['sportswear', 'streetstyle', 'style', 'styleblogger', 'outfitoftheday']
# >>> ['fashionista']
# ['nutrition', 'health', 'wellness', 'healthy']
# >>> ['healthylifestyle']
# ['fashion', 'sportswear', 'outfitoftheday', 'streetstyle', 'fashionblogger']
# >>> ['style', 'styleblogger', 'outfit']
# ['travel', 'sportswear', 'travelphotography', 'travelblogger']
# >>> ['wanderlust']
# ['style', 'sportswear', 'fashionblogger', 'styleblogger']
# >>> ['outfit', 'fashion', 'streetstyle', 'outfitoftheday', 'fashionista']
# ['snow', 'healthy', 'wellness', 'health']
# >>> ['nutrition', 'healthylifestyle']
# ['travel', 'snow', 'summer', 'wanderlust', 'travelphotography']
# >>> ['vacation', 'travelblogger', 'adventure']
# ['travel', 'travelphotography', 'wanderlust', 'adventure']
# >>> ['vacation', 'travelblogger']
# ['travel', 'snow', 'adventure', 'travelphotography', 'wanderlust']
# >>> ['travelblogger', 'vacation']
# ['travel', 'snow', 'travelblogger', 'adventure', 'travelphotography']
# >>> ['wanderlust', 'vacation']
# ['travel', 'snow', 'adventure', 'vacation', 'travelblogger']
# >>> ['wanderlust', 'travelphotography']
# ['loveyou', 'adventure', 'travel', 'travelblogger']
# >>> ['wanderlust']
# ['mood', 'quote', 'goodvibes', 'quotes']
# >>> ['selflove']
# ['travel', 'mood', 'adventure', 'travelphotography']
# >>> ['vacation']
# ['travel', 'mood', 'adventure', 'travelphotography', 'travelblogger']
# >>> ['vacation']
# ['fashion', 'style', 'fashionista', 'outfit']
# >>> ['styleblogger', 'streetstyle', 'fashionblogger']
# ['fashion', 'fashionaddict', 'outfit', 'streetstyle', 'fashionblogger']
# >>> ['styleblogger', 'style']
# ['fashion', 'leather', 'styleblogger', 'fashionista', 'style']
# >>> ['outfitoftheday', 'streetstyle', 'fashionblogger', 'outfit']
# ['fashion', 'fashionista', 'outfit', 'style', 'streetstyle']
# >>> ['fashionblogger']
# ['fashion', 'outfitoftheday', 'styleblogger']
# >>> ['fashionista', 'fashionblogger', 'outfit', 'streetstyle', 'style']
# ['style', 'fashion', 'fashionblogger', 'styleblogger', 'outfitoftheday']
# >>> ['outfit', 'fashionista']
# ['fashion', 'couple', 'fashionista', 'outfitoftheday', 'style']
# >>> ['styleblogger', 'streetstyle', 'fashionblogger', 'outfit']
# ['fashion', 'fashionista', 'fashionblogger', 'streetstyle']
# >>> ['outfit', 'styleblogger', 'outfitoftheday', 'style']
# ['fashion', 'art', 'outfit', 'streetstyle', 'painting']
# >>> ['color']
# ['fashion', 'streetstyle', 'fashionblogger', 'fashionista', 'outfitoftheday']
# >>> ['outfit', 'style']
# ['model', 'fashion', 'fashionblogger', 'style']
# >>> ['fashionista']
# ['fashion', 'styleblogger', 'outfit', 'style']
# >>> ['streetstyle', 'fashionblogger', 'fashionista', 'outfitoftheday']
# ['fashion', 'fashionista', 'outfitoftheday', 'streetstyle', 'style']
# >>> ['fashionblogger', 'styleblogger', 'outfit']
# ['fashion', 'styleblogger', 'fashionblogger', 'streetstyle', 'fashionista']
# >>> ['outfit', 'style', 'outfitoftheday']
# ['fashion', 'streetstyle', 'fashionblogger', 'outfitoftheday', 'styleblogger']
# >>> ['outfit', 'style', 'fashionista']
# ['style', 'fashion', 'streetstyle', 'styleblogger']
# >>> ['outfit', 'fashionblogger']
# ['fashion', 'white', 'fashionblogger', 'streetstyle', 'outfit']
# >>> ['outfitoftheday', 'style', 'fashionista', 'styleblogger']
# ['fashion', 'style', 'fashionista', 'fashionblogger', 'outfit']
# >>> ['outfitoftheday', 'styleblogger', 'streetstyle']
# ['fashion', 'streetstyle', 'fashionblogger', 'styleblogger']
# >>> ['outfit']
# ['fashion', 'fashionblogger', 'styleblogger']
# >>> ['outfitoftheday', 'streetstyle']
# ['fashion', 'styleblogger', 'fashionblogger', 'outfitoftheday', 'outfit']
# >>> ['style', 'fashionista']
# ['fashion', 'style', 'fashionblogger', 'outfitoftheday']
# >>> ['styleblogger']
# ['fashionblogger', 'fashion', 'outfit', 'streetstyle', 'style']
# >>> ['fashionista', 'styleblogger']
# ['fashion', 'outfit', 'fashionista', 'outfitoftheday']
# >>> ['streetstyle', 'fashionblogger', 'style', 'styleblogger']
# ['necklace', 'fashion', 'streetstyle', 'outfit', 'styleblogger']
# >>> ['fashionista', 'style']
# ['fashion', 'streetstyle', 'fashionista', 'style']
# >>> ['fashionblogger', 'outfit', 'styleblogger']
# ['fashion', 'detail', 'outfitoftheday', 'styleblogger', 'style']
# >>> ['fashionblogger']
# ['shop', 'fashion', 'style', 'styleblogger', 'streetstyle']
# >>> ['outfit', 'fashionista', 'fashionblogger', 'outfitoftheday']
# ['makeup', 'fashion', 'style', 'outfitoftheday', 'fashionista']
# >>> ['streetstyle', 'fashionblogger', 'outfit', 'styleblogger']
# ['makeup', 'fashion', 'maccosmetics', 'style', 'styleblogger']
# >>> ['fashionblogger', 'fashionista', 'outfit', 'streetstyle']
# ['pet', 'cutepet', 'pets']
# >>> ['animal', 'cutenessoverload', 'cuteanimals', 'animals', 'cutepetclub', 'petsofourworld']
# ['always', 'quote', 'goodvibes', 'goals', 'inspiration']
# >>> ['selflove']
# ['travel', 'throwback', 'travelblogger', 'travelphotography', 'vacation']
# >>> ['wanderlust', 'adventure']
# ['boat', 'throwback', 'travel', 'wanderlust', 'travelblogger']
# >>> ['adventure']
# ['throwback', 'wanderlust', 'adventure', 'vacation']
# >>> ['travelphotography', 'travelblogger', 'travel']
# ['hair', 'outfit', 'streetstyle', 'outfitoftheday', 'fashionblogger']
# >>> ['fashionista', 'styleblogger', 'style', 'fashion']
# ['hair', 'art', 'artistzone', 'artwork']
# >>> ['creative', 'drawing', 'color', 'painting', 'colors']
# ['art', 'sun', 'artwork', 'painting', 'creative']
# >>> ['drawing', 'artistzone']
# ['quote', 'goodvibes', 'quotes', 'selflove']
# >>> ['goals', 'inspiration']
# ['style', 'oldtimes', 'fashionblogger', 'fashionista', 'fashion']
# >>> ['styleblogger']
# ['travel', 'oldtimes', 'tourist', 'wanderlust', 'travelphotography']
# >>> ['travelblogger']
# ['health', 'beauty', 'wellness', 'healthylifestyle', 'nutrition']
# >>> ['healthy']
# ['beauty', 'health', 'wellness', 'healthylifestyle']
# >>> ['nutrition']
# ['beauty', 'fashion', 'fashionblogger', 'outfitoftheday', 'styleblogger']
# >>> ['fashionista']
# ['yummy', 'instafood', 'foodie', 'food']
# >>> ['bonappetit', 'foodporn', 'foodphotography', 'foodlover', 'delicious']
# ['homemade', 'yummy', 'instafood', 'foodie']
# >>> ['delicious', 'foodphotography', 'tasty', 'foodstagram', 'foodlover', 'bonappetit', 'food', 'foodporn']
# ['homemade', 'organic', 'food', 'tasty', 'bonappetit']
# >>> ['foodlover', 'foodphotography', 'foodporn', 'delicious', 'foodstagram', 'yummy', 'instafood', 'foodie']
# ['yummy', 'food', 'delicious', 'foodie']
# >>> ['foodstagram']
# ['foodporn', 'food', 'yummy', 'foodlover', 'delicious']
# >>> ['foodstagram', 'foodphotography', 'bonappetit', 'instafood', 'foodie']
# ['chocolate', 'yummy', 'foodie', 'food', 'instafood']
# >>> ['foodlover', 'foodphotography']
# ['yummy', 'foodporn', 'foodie', 'instafood', 'tasty']
# >>> ['bonappetit', 'delicious', 'foodlover', 'foodstagram', 'foodphotography']
# ['yummy', 'delicious', 'foodporn', 'foodie', 'foodstagram']
# >>> ['foodphotography', 'instafood']
# ['baby', 'yummy', 'foodstagram', 'tasty', 'food']
# >>> ['instafood', 'delicious', 'bonappetit']
# ['yummy', 'instafood', 'foodporn']
# >>> ['tasty']
# ['yummy', 'tasty', 'foodphotography', 'delicious']
# >>> ['bonappetit', 'instafood', 'foodporn', 'foodie', 'foodlover', 'foodstagram']
# ['yummy', 'foodie', 'tasty', 'foodporn']
# >>> ['food', 'foodstagram', 'delicious', 'bonappetit', 'instafood', 'foodlover']
# ['delish', 'yummy', 'foodstagram', 'foodporn', 'instafood']
# >>> ['tasty', 'foodlover', 'delicious', 'food']
# ['yummy', 'foodlover', 'bonappetit', 'foodie', 'tasty']
# >>> ['foodstagram', 'foodporn', 'foodphotography']
# ['yummy', 'foodlover', 'foodphotography']
# >>> ['foodporn']
# ['yummy', 'foodie', 'instafood']
# >>> ['tasty', 'bonappetit']
# ['yummy', 'foodlover', 'tasty']
# >>> ['foodphotography', 'foodstagram', 'delicious', 'instafood', 'bonappetit']
# ['yummy', 'delicious', 'foodlover']
# >>> ['tasty', 'foodie', 'bonappetit', 'food', 'foodphotography', 'foodporn']
# ['yummy', 'foodie', 'foodphotography', 'foodlover']
# >>> ['tasty', 'instafood', 'food', 'bonappetit', 'foodporn', 'delicious', 'foodstagram']
# ['food', 'yummy', 'foodphotography', 'foodlover', 'tasty']
# >>> ['foodporn', 'instafood']
# ['yummy', 'delicious', 'food', 'bonappetit', 'foodie']
# >>> ['foodlover', 'instafood', 'foodporn', 'foodphotography', 'tasty', 'foodstagram']
# ['food', 'yummy', 'foodstagram', 'delicious']
# >>> ['instafood']
# ['yummy', 'bonappetit', 'foodstagram', 'food', 'delicious']
# >>> ['foodphotography']
# ['yummy', 'foodporn', 'bonappetit', 'delicious', 'foodstagram']
# >>> ['tasty', 'foodlover']
# ['yummy', 'food', 'delicious']
# >>> ['foodporn', 'instafood', 'tasty', 'foodstagram']
# ['yummy', 'foodie', 'tasty', 'food']
# >>> ['bonappetit', 'delicious', 'foodstagram', 'foodphotography']
# ['yummy', 'foodstagram', 'instafood', 'foodlover', 'foodphotography']
# >>> ['delicious', 'foodie', 'tasty', 'food', 'foodporn']
# ['yum', 'hungry', 'yummy', 'instafood', 'food']
# >>> ['foodie', 'foodlover', 'foodporn', 'tasty', 'foodstagram', 'foodphotography', 'bonappetit', 'delicious']
# ['yummy', 'foodie', 'bonappetit', 'foodlover']
# >>> ['food']
# ['yummy', 'foodlover', 'tasty', 'foodporn']
# >>> ['instafood', 'delicious', 'bonappetit', 'food', 'foodstagram', 'foodie', 'foodphotography']
# ['yummy', 'delicious', 'foodlover', 'bonappetit']
# >>> ['tasty', 'foodphotography', 'foodie']
# ['model', 'fashion', 'amazing', 'style', 'streetstyle']
# >>> ['outfit', 'fashionblogger', 'outfitoftheday', 'styleblogger', 'fashionista']
# ['model', 'fashion', 'fashionista', 'outfit', 'outfitoftheday']
# >>> ['styleblogger', 'fashionblogger']
# ['model', 'fashion', 'styleblogger', 'style']
# >>> ['streetstyle', 'fashionblogger', 'outfitoftheday', 'outfit']
# ['model', 'stylish', 'style', 'outfit', 'fashionblogger']
# >>> ['outfitoftheday']
# ['model', 'fashion', 'fashionblogger', 'outfit', 'style']
# >>> ['outfitoftheday', 'styleblogger', 'streetstyle']
# ['cake', 'delicious', 'bonappetit', 'tasty']
# >>> ['foodporn', 'foodlover', 'foodstagram', 'instafood']
# ['cake', 'food', 'instafood', 'foodstagram', 'yummy']
# >>> ['delicious', 'bonappetit', 'tasty', 'foodporn', 'foodlover', 'foodphotography', 'foodie']
# ['eye', 'art', 'painting', 'artwork', 'creative']
# >>> ['color', 'drawing']
# ['eye', 'pet', 'pets', 'cuteanimals', 'cutenessoverload']
# >>> ['animaladdicts', 'animals', 'cutepet']
# ['drawing', 'green', 'colors', 'artwork', 'painting']
# >>> ['artistzone', 'creative', 'color', 'art']
# ['food', 'green', 'foodie', 'yummy', 'delicious']
# >>> ['instafood', 'foodporn', 'foodstagram', 'foodlover', 'bonappetit', 'tasty', 'foodphotography']
# ['adventure', 'travelphotography', 'vacation', 'wanderlust']
# >>> ['travel']
# ['quote', 'motivation', 'quotes', 'selflove']
# >>> ['inspiration', 'goodvibes']
# ['fashion', 'outfit', 'fashionblogger', 'fashionista']
# >>> ['styleblogger', 'outfitoftheday', 'style', 'streetstyle']
# ['quote', 'motivation', 'quotes', 'goodvibes', 'inspiration']
# >>> ['goals', 'selflove']
# ['fashion', 'flower', 'outfit', 'fashionblogger', 'fashionista']
# >>> ['outfitoftheday', 'streetstyle', 'style']
# ['art', 'color', 'creative', 'painting', 'artistzone']
# >>> ['colors']
# ['photo', 'outfit', 'kid', 'outfitoftheday', 'fashion']
# >>> ['style']
# ['style', 'beautiful', 'styleblogger', 'outfit']
# >>> ['outfitoftheday']
# ['funny', 'pet', 'cutepetclub', 'petsofourworld']
# >>> ['cuteanimals']
# ['daily', 'pet', 'animaladdicts', 'animals']
# >>> ['animal', 'petsofourworld', 'cutenessoverload', 'cuteanimals', 'pets', 'cutepetclub', 'cutepet']
# ['travel', 'daily', 'travelling', 'wanderlust', 'adventure']
# >>> ['travelphotography', 'vacation']
# ['daily', 'big', 'yummy', 'foodstagram', 'foodporn']
# >>> ['foodie', 'foodphotography', 'bonappetit']
# ['spring', 'travel', 'adventure', 'wanderlust']
# >>> ['vacation']
# ['photocam', 'daily', 'wanderlust', 'travelphotography', 'adventure']
# >>> ['vacation']
# ['daily', 'wanderlust', 'adventure', 'vacation', 'travelblogger']
# >>> ['travel', 'travelphotography']
# ['pet', 'cutepet', 'petsofourworld', 'animals', 'animal']
# >>> ['pets', 'cutepetclub', 'cuteanimals', 'cutenessoverload']
# ['beach', 'travel', 'travelphotography', 'vacation']
# >>> ['adventure']
# ['beach', 'painting', 'creative', 'artwork', 'art']
# >>> ['color', 'colors', 'artistzone']
# ['beach', 'goodvibes', 'inspiration', 'quotes', 'quote']
# >>> ['goals', 'selflove']
# ['beach', 'vacation', 'adventure', 'travel', 'travelphotography']
# >>> ['wanderlust', 'travelblogger']
# ['beach', 'wanderlust', 'travel', 'vacation']
# >>> ['travelblogger', 'travelphotography']
# ['beach', 'holiday', 'travel', 'travelphotography', 'vacation']
# >>> ['wanderlust', 'adventure']
# ['beach', 'nofilter', 'travel', 'adventure', 'travelblogger']
# >>> ['wanderlust']
# ['beach', 'vacation', 'travel', 'travelblogger', 'adventure']
# >>> ['wanderlust']
# ['beach', 'vacation', 'ocean', 'wanderlust', 'travelphotography']
# >>> ['travelblogger']
# ['quote', 'quotes', 'goodvibes', 'inspiration', 'selflove']
# >>> ['goals']
# ['travel', 'nature', 'amazing', 'travelphotography', 'vacation']
# >>> ['wanderlust']
# ['quote', 'selflove', 'inspiration', 'goals']
# >>> ['goodvibes']
# ['inspiration', 'quote', 'yoga', 'goals', 'selflove']
# >>> ['goodvibes']
# ['faith', 'inspiration', 'goodvibes', 'quotes']
# >>> ['selflove', 'quote']
# ['word', 'quote', 'inspiration', 'quotes', 'goodvibes']
# >>> ['goals', 'selflove']
# ['quote', 'inspiration', 'quotes', 'selflove', 'goals']
# >>> ['goodvibes']
# ['iloveyou', 'quote', 'goodvibes', 'goals', 'quotes']
# >>> ['selflove', 'inspiration']
# ['quote', 'goals', 'quotes', 'selflove', 'inspiration']
# >>> ['goodvibes']
# ['inspiration', 'quotes', 'goodvibes']
# >>> ['selflove', 'quote']
# ['health', 'memes', 'healthy', 'healthylifestyle', 'nutrition']
# >>> ['wellness']
# ['style', 'fashion', 'styleblogger']
# >>> ['outfit', 'streetstyle', 'fashionista']
# ['quote', 'quotes', 'inspiration', 'selflove', 'goals']
# >>> ['goodvibes']
# ['inspiration', 'selflove', 'quote', 'quotes', 'goodvibes']
# >>> ['goals']
# ['entrepreneur', 'quote', 'goodvibes', 'quotes']
# >>> ['goals']
# ['quote', 'selflove', 'goals', 'inspiration', 'goodvibes']
# >>> ['quotes']
# ['quote', 'inspiration', 'goodvibes', 'goals', 'selflove']
# >>> ['quotes']
# ['quote', 'goodvibes', 'quotes', 'inspiration', 'selflove']
# >>> ['goals']
# ['true', 'quote', 'selflove', 'goals']
# >>> ['quotes', 'goodvibes', 'inspiration']
# ['mylife', 'quote', 'selflove', 'quotes', 'goals']
# >>> ['inspiration', 'goodvibes']
# ['pet', 'animals', 'cutepet', 'cuteanimals']
# >>> ['pets', 'animal', 'animaladdicts', 'petsofourworld', 'cutepetclub']
# ['quote', 'goodvibes', 'inspiration', 'goals', 'quotes']
# >>> ['selflove']
# ['food', 'instafood', 'foodie', 'foodporn', 'foodstagram']
# >>> ['foodlover', 'bonappetit', 'delicious']
# ['eatclean', 'eat', 'food', 'instafood', 'foodie']
# >>> ['foodlover', 'bonappetit', 'delicious', 'yummy', 'tasty', 'foodporn', 'foodstagram']
# ['food', 'foodie', 'instafood']
# >>> ['foodphotography', 'foodlover', 'bonappetit', 'tasty', 'foodporn', 'yummy']
# ['style', 'food', 'outfit', 'fashionista', 'fashionblogger']
# >>> ['outfitoftheday']
# ['foodporn', 'tasty', 'delicious', 'foodlover']
# >>> ['foodphotography', 'foodie']
# ['foodporn', 'food', 'foodphotography', 'foodie', 'tasty']
# >>> ['yummy', 'delicious', 'foodstagram']
# ['lunch', 'food', 'delicious', 'foodie', 'tasty']
# >>> ['foodphotography', 'foodporn']
# ['food', 'foodphotography', 'delicious', 'bonappetit', 'foodporn']
# >>> ['foodstagram']
# ['lunch', 'coffee', 'food', 'foodie', 'foodstagram']
# >>> ['tasty', 'foodphotography', 'bonappetit', 'foodporn', 'yummy', 'delicious']
# ['food', 'foodstagram', 'foodlover', 'foodie', 'delicious']
# >>> ['instafood', 'yummy', 'tasty', 'foodphotography', 'bonappetit', 'foodporn']
# ['daily', 'food', 'foodphotography', 'yummy']
# >>> ['foodporn', 'instafood', 'delicious', 'tasty']
# ['food', 'foodlover', 'foodie', 'tasty', 'bonappetit']
# >>> ['delicious', 'foodporn', 'foodstagram', 'foodphotography']
# ['food', 'foodie', 'instafood', 'foodphotography', 'delicious']
# >>> ['foodporn', 'bonappetit', 'yummy', 'tasty', 'foodlover']
# ['food', 'delicious', 'foodphotography', 'bonappetit']
# >>> ['instafood', 'yummy', 'foodie', 'foodporn']
# ['food', 'tasty', 'foodphotography', 'foodie', 'bonappetit']
# >>> ['foodlover', 'delicious', 'yummy', 'instafood', 'foodstagram']
# ['dessert', 'food', 'sweet', 'tasty', 'foodlover']
# >>> ['instafood', 'yummy', 'foodporn', 'bonappetit']
# ['baking', 'food', 'foodie', 'bonappetit']
# >>> ['foodporn', 'foodphotography']
# ['foodie', 'food', 'dinner', 'foodphotography', 'foodlover']
# >>> ['instafood', 'bonappetit', 'foodporn', 'foodstagram', 'yummy', 'delicious', 'tasty']
# ['style', 'shoe', 'fashionista', 'styleblogger']
# >>> ['fashion', 'outfitoftheday', 'outfit']
# ['style', 'shoe', 'shopping', 'streetstyle', 'styleblogger']
# >>> ['fashionista', 'fashionblogger', 'outfit', 'fashion']
# ['inspiration', 'shoe', 'selflove', 'quotes']
# >>> ['goals']
# ['designer', 'photooftheday', 'fashion', 'fashionblogger', 'outfitoftheday']
# >>> ['outfit', 'styleblogger']
# ['daily', 'fashion', 'styleblogger', 'streetstyle', 'outfitoftheday']
# >>> ['outfit', 'fashionista', 'fashionblogger']
# ['style', 'styleblogger', 'fashionblogger', 'fashionista', 'streetstyle']
# >>> ['outfit', 'outfitoftheday', 'fashion']
# ['style', 'styleblogger', 'outfitoftheday', 'fashion', 'streetstyle']
# >>> ['fashionblogger', 'fashionista']
# ['goodvibes', 'goodtimes', 'quotes', 'quote', 'selflove']
# >>> ['goals']
# ['travel', 'goodtimes', 'travelphotography', 'travelblogger', 'adventure']
# >>> ['wanderlust']
# ['travel', 'goodtimes', 'travelphotography', 'adventure', 'vacation']
# >>> ['wanderlust', 'travelblogger']
# ['goodtimes', 'tired', 'adventure', 'travelblogger', 'travelphotography']
# >>> ['travel']
# ['family', 'pet', 'animaladdicts', 'cuteanimals', 'animals']
# >>> ['petsofourworld']
# ['style', 'family', 'styleblogger', 'fashionista']
# >>> ['fashion', 'outfit']
# ['travel', 'travelblogger', 'wanderlust', 'adventure', 'travelphotography']
# >>> ['vacation']
# ['family', 'pet', 'pets', 'animaladdicts', 'animals']
# >>> ['petsofourworld', 'cuteanimals', 'cutenessoverload', 'cutepet']
# ['art', 'tired', 'artistzone', 'painting', 'color']
# >>> ['drawing', 'creative']
# ['health', 'tired', 'healthylifestyle', 'wellness']
# >>> ['healthy']
# ['quote', 'tired', 'quotes', 'goodvibes']
# >>> ['inspiration', 'selflove', 'goals']
# ['vacation', 'tired', 'travelblogger', 'travel']
# >>> ['travelphotography']
# ['travel', 'tourism', 'school', 'wanderlust', 'adventure']
# >>> ['travelblogger']
# ['plant', 'wanderlust', 'school', 'travelblogger', 'adventure']
# >>> ['travel', 'vacation']
# ['bag', 'travel', 'school', 'travelphotography', 'vacation']
# >>> ['travelblogger']
# ['fashionblogger', 'black', 'outfitoftheday', 'fashion', 'streetstyle']
# >>> ['outfit', 'style']
# ['dark', 'travel', 'black', 'adventure', 'wanderlust']
# >>> ['travelblogger', 'vacation']
# ['tattoo', 'art', 'color', 'drawing', 'artwork']
# >>> ['colors', 'painting']
# ['tattoo', 'art', 'drawing', 'painting', 'artwork']
# >>> ['color']
# ['art', 'color', 'painting', 'colors', 'artistzone']
# >>> ['creative', 'artwork', 'drawing']
# ['art', 'drawing', 'creative', 'painting', 'color']
# >>> ['artwork', 'artistzone']
# ['art', 'artistzone', 'color']
# >>> ['artwork', 'painting', 'colors', 'drawing', 'creative']
# ['art', 'colors', 'artistzone', 'painting', 'artwork']
# >>> ['color', 'drawing', 'creative']
# ['art', 'artistzone', 'drawing', 'painting', 'color']
# >>> ['creative', 'artwork', 'colors']
# ['art', 'color', 'artwork', 'painting']
# >>> ['artistzone', 'drawing']
# ['art', 'painting', 'creative', 'artistzone', 'artwork']
# >>> ['drawing']
# ['art', 'colors', 'artistzone']
# >>> ['color', 'drawing', 'artwork']
# ['art', 'artistzone', 'color']
# >>> ['artwork', 'drawing', 'creative']
# ['art', 'color', 'colors', 'drawing', 'artwork']
# >>> ['artistzone', 'creative']
# ['art', 'colors', 'artwork', 'creative']
# >>> ['drawing', 'color', 'artistzone', 'painting']
# ['art', 'artwork', 'colors', 'creative', 'drawing']
# >>> ['artistzone', 'color', 'painting']
# ['art', 'color', 'drawing', 'artwork', 'painting']
# >>> ['artistzone', 'colors']
# ['art', 'drawing', 'color', 'painting']
# >>> ['creative', 'artwork', 'colors', 'artistzone']
# ['art', 'drawing', 'colors']
# >>> ['painting', 'artistzone', 'color', 'creative', 'artwork']
# ['art', 'color', 'drawing', 'artwork', 'painting']
# >>> ['creative', 'colors']
# ['art', 'creative', 'artistzone']
# >>> ['painting', 'colors', 'drawing', 'artwork', 'color']
# ['art', 'drawing', 'painting', 'artwork', 'creative']
# >>> ['colors', 'color']
# ['art', 'artistzone', 'artwork', 'painting', 'drawing']
# >>> ['color', 'colors', 'creative']
# ['art', 'creative', 'color', 'artwork', 'drawing']
# >>> ['colors', 'artistzone', 'painting']
# ['art', 'creative', 'artwork', 'color', 'artistzone']
# >>> ['colors', 'painting', 'drawing']
# ['art', 'artwork', 'creative', 'artistzone']
# >>> ['colors', 'painting', 'drawing', 'color']
# ['art', 'drawing', 'color', 'colors', 'artistzone']
# >>> ['artwork']
# ['art', 'artistzone', 'colors', 'creative']
# >>> ['artwork', 'drawing', 'painting']
# ['art', 'artwork', 'artistzone']
# >>> ['drawing']
# ['art', 'drawing', 'color', 'artistzone']
# >>> ['painting', 'colors', 'creative', 'artwork']
# ['art', 'drawing', 'colors']
# >>> ['color']
# ['art', 'painting', 'artistzone', 'drawing', 'color']
# >>> ['creative']
# ['art', 'artistzone', 'drawing', 'painting', 'artwork']
# >>> ['creative', 'colors', 'color']
# ['art', 'drawing', 'artwork', 'color', 'artistzone']
# >>> ['creative', 'colors', 'painting']
# ['art', 'drawing', 'creative', 'artistzone']
# >>> ['color', 'colors', 'artwork', 'painting']
# ['art', 'artistzone', 'color', 'drawing', 'artwork']
# >>> ['creative', 'colors', 'painting']
# ['art', 'color', 'colors', 'artwork', 'drawing']
# >>> ['painting']
# ['art', 'color', 'painting', 'artwork']
# >>> ['drawing', 'colors', 'creative', 'artistzone']
# ['art', 'painting', 'artistzone', 'drawing']
# >>> ['color', 'creative', 'artwork', 'colors']
# ['art', 'artwork', 'colors', 'creative']
# >>> ['painting', 'color', 'artistzone', 'drawing']
# ['art', 'drawing', 'creative', 'artistzone', 'artwork']
# >>> ['painting', 'colors']
# ['art', 'artwork', 'color', 'colors', 'painting']
# >>> ['drawing', 'creative', 'artistzone']
# ['art', 'creative', 'artwork', 'color']
# >>> ['colors', 'artistzone']
# ['art', 'artistzone', 'color', 'artwork', 'painting']
# >>> ['colors']
# ['art', 'creative', 'colors', 'drawing', 'painting']
# >>> ['artistzone', 'color', 'artwork']
# ['art', 'colors', 'artistzone', 'painting']
# >>> ['drawing']
# ['art', 'drawing', 'artistzone', 'creative', 'color']
# >>> ['painting', 'artwork', 'colors']
# ['art', 'artistzone', 'creative', 'artwork', 'color']
# >>> ['painting', 'colors', 'drawing']
# ['art', 'artistzone', 'color']
# >>> ['creative']
# ['art', 'color', 'artistzone', 'drawing', 'colors']
# >>> ['artwork', 'painting', 'creative']
# ['art', 'creative', 'painting', 'colors']
# >>> ['artistzone', 'artwork', 'color', 'drawing']
# ['photooftheday', 'art', 'color', 'creative', 'painting']
# >>> ['colors', 'drawing', 'artistzone']
# ['art', 'colorful', 'colors', 'creative', 'color']
# >>> ['drawing', 'painting']
# ['daily', 'fashion', 'art', 'painting', 'artwork']
# >>> ['artistzone', 'creative']
# ['collector', 'art', 'color', 'artistzone']
# >>> ['painting', 'artwork', 'colors', 'creative']
# ['art', 'artistzone', 'creative', 'drawing']
# >>> ['artwork']
# ['hair', 'fashion', 'style', 'outfit', 'fashionista']
# >>> ['streetstyle', 'styleblogger', 'outfitoftheday', 'fashionblogger']
# ['art', 'artwork', 'artistzone', 'painting']
# >>> ['colors', 'color', 'creative', 'drawing']
# ['landscape', 'art', 'color', 'artwork', 'artistzone']
# >>> ['creative', 'drawing']
# ['travel', 'nature', 'travelblogger', 'vacation', 'wanderlust']
# >>> ['travelphotography', 'adventure']
# ['travel', 'mountains', 'adventure', 'travelblogger', 'vacation']
# >>> ['wanderlust']
# ['beauty', 'style', 'beautiful', 'fashionblogger', 'streetstyle']
# >>> ['outfit']
# ['explore', 'style', 'fashion', 'outfitoftheday', 'outfit']
# >>> ['fashionblogger', 'styleblogger', 'streetstyle']
# ['fashion', 'photooftheday', 'beautiful', 'fashionblogger', 'outfitoftheday']
# >>> ['style', 'styleblogger', 'fashionista', 'outfit']
# ['beauty', 'travel', 'adventure', 'travelphotography', 'wanderlust']
# >>> ['vacation', 'travelblogger']
# ['style', 'fitness', 'fashion', 'fashionista', 'fashionblogger']
# >>> ['styleblogger', 'streetstyle']
# ['quotes', 'motivation', 'photoshoot', 'quote', 'goals']
# >>> ['selflove']
# ['makeup', 'fashion', 'style', 'streetstyle', 'outfit']
# >>> ['fashionista']
# ['travel', 'travelphotography', 'adventure', 'travelblogger', 'vacation']
# >>> ['wanderlust']
# ['pet', 'animaladdicts', 'animals', 'pets', 'cutenessoverload']
# >>> ['cutepet', 'cuteanimals', 'petsofourworld']
# ['photooftheday', 'quotes', 'lifestyle', 'inspiration', 'quote']
# >>> ['goals']
# ['wanderlust', 'adventure', 'vacation', 'travel', 'travelblogger']
# >>> ['travelphotography']
# ['photooftheday', 'inspiration', 'green', 'goals', 'selflove']
# >>> ['quotes']
# ['happy', 'style', 'explore', 'styleblogger', 'fashionblogger']
# >>> ['outfit', 'fashionista', 'outfitoftheday']
# ['travel', 'wanderlust', 'travelblogger']
# >>> ['travelphotography', 'vacation']
# ['photooftheday', 'wanderlust', 'travel', 'travelblogger', 'vacation']
# >>> ['adventure']
# ['websta', 'photooftheday', 'healthy', 'healthylifestyle', 'health']
# >>> ['wellness', 'nutrition']
# ['wellness', 'healthy', 'nutrition', 'health']
# >>> ['healthylifestyle']
# ['artwork', 'drawing', 'art', 'creative', 'colors']
# >>> ['color']
# ['cute', 'pet', 'pets', 'animals', 'animal']
# >>> ['petsofourworld', 'cutepetclub', 'cuteanimals']
# ['fashion', 'outfitoftheday', 'styleblogger', 'fashionblogger', 'style']
# >>> ['outfit']
# ['design', 'illustration', 'art', 'creative', 'colors']
# >>> ['color', 'artwork', 'artistzone', 'drawing', 'painting']
# ['family', 'adventure', 'travelblogger', 'travel', 'wanderlust']
# >>> ['travelphotography']
# ['vacation', 'family', 'travel', 'adventure']
# >>> ['wanderlust', 'travelblogger']
# ['fashion', 'style', 'styleblogger', 'streetstyle', 'outfitoftheday']
# >>> ['fashionista', 'outfit', 'fashionblogger']
# ['fashion', 'streetstyle', 'outfit', 'fashionista', 'styleblogger']
# >>> ['outfitoftheday', 'style', 'fashionblogger']
# ['fashion', 'outfit', 'streetstyle', 'style', 'outfitoftheday']
# >>> ['styleblogger', 'fashionista', 'fashionblogger']
# ['beauty', 'style', 'fashion', 'outfit', 'streetstyle']
# >>> ['styleblogger', 'fashionblogger', 'fashionista', 'outfitoftheday']
# ['fashion', 'fashionista', 'streetstyle', 'styleblogger']
# >>> ['style']
# ['fashion', 'streetstyle', 'outfitoftheday', 'fashionista', 'style']
# >>> ['fashionblogger']
# ['fashion', 'fashionista', 'styleblogger', 'style', 'fashionblogger']
# >>> ['outfit', 'outfitoftheday', 'streetstyle']
# ['fashion', 'styleblogger', 'outfit', 'fashionista', 'fashionblogger']
# >>> ['streetstyle', 'style']
# ['fashion', 'outfitoftheday', 'fashionista', 'streetstyle', 'fashionblogger']
# >>> ['style', 'styleblogger', 'outfit']
# ['fashion', 'outfit', 'style', 'outfitoftheday', 'fashionblogger']
# >>> ['fashionista', 'streetstyle']
# ['fashion', 'styleblogger', 'style']
# >>> ['fashionista', 'outfitoftheday', 'fashionblogger', 'streetstyle', 'outfit']
# ['fashion', 'streetstyle', 'outfit', 'styleblogger', 'fashionista']
# >>> ['style']
# ['fashion', 'styleblogger', 'style', 'outfit', 'fashionblogger']
# >>> ['outfitoftheday', 'streetstyle']
# ['fashion', 'style', 'fashionblogger', 'outfit', 'fashionista']
# >>> ['streetstyle']
# ['fashion', 'outfit', 'styleblogger', 'style', 'outfitoftheday']
# >>> ['fashionblogger', 'streetstyle', 'fashionista']
# ['fashion', 'style', 'outfit', 'streetstyle']
# >>> ['styleblogger', 'fashionista', 'outfitoftheday']
# ['fashion', 'outfit', 'streetstyle', 'fashionista', 'outfitoftheday']
# >>> ['style', 'styleblogger']
# ['fashion', 'outfit', 'outfitoftheday', 'fashionista', 'streetstyle']
# >>> ['style', 'fashionblogger', 'styleblogger']
# ['fashion', 'fashionista', 'style', 'styleblogger']
# >>> ['outfitoftheday', 'fashionblogger']
# ['fashion', 'fashionblogger', 'outfitoftheday', 'streetstyle', 'style']
# >>> ['fashionista', 'styleblogger', 'outfit']
# ['portrait', 'painting', 'artwork', 'color']
# >>> ['artistzone']
# ['fashion', 'streetstyle', 'outfit']
# >>> ['outfitoftheday', 'fashionista', 'styleblogger']
# ['fashion', 'outfitoftheday', 'style', 'fashionista', 'styleblogger']
# >>> ['fashionblogger', 'outfit', 'streetstyle']
# ['fashion', 'outfit', 'style', 'outfitoftheday']
# >>> ['fashionblogger', 'fashionista', 'streetstyle']
# ['outfit', 'moda', 'streetstyle', 'outfitoftheday', 'style']
# >>> ['fashionblogger', 'fashionista', 'fashion']
# ['original', 'photooftheday', 'travel', 'wanderlust', 'vacation']
# >>> ['adventure', 'travelphotography', 'travelblogger']
# ['fashion', 'style', 'outfit']
# >>> ['styleblogger', 'streetstyle', 'fashionista', 'fashionblogger']
# ['fashion', 'streetstyle', 'fashionista', 'styleblogger', 'style']
# >>> ['outfitoftheday']
# ['style', 'fashion', 'outfit', 'fashionblogger', 'outfitoftheday']
# >>> ['fashionista', 'streetstyle', 'styleblogger']
# ['fashion', 'outfit', 'styleblogger', 'fashionblogger', 'outfitoftheday']
# >>> ['fashionista', 'style']
# ['fashion', 'styleblogger', 'streetstyle', 'style']
# >>> ['outfitoftheday', 'fashionblogger']
# ['fashion', 'outfit', 'style', 'fashionblogger']
# >>> ['fashionista']
# ['fashion', 'streetstyle', 'style', 'fashionista', 'styleblogger']
# >>> ['outfit']
# ['fashion', 'blog', 'style', 'fashionista', 'outfit']
# >>> ['fashionblogger', 'outfitoftheday']
# ['fashion', 'style', 'styleblogger', 'fashionista']
# >>> ['outfit', 'outfitoftheday', 'streetstyle']
# ['baby', 'fashion', 'dress', 'style', 'fashionblogger']
# >>> ['styleblogger', 'streetstyle', 'outfit', 'fashionista', 'outfitoftheday']
# ['fashion', 'streetstyle', 'style', 'outfitoftheday']
# >>> ['fashionista', 'outfit', 'fashionblogger']
# ['fashion', 'fashionista', 'outfitoftheday', 'outfit']
# >>> ['styleblogger', 'fashionblogger']
# ['fashion', 'style', 'styleblogger', 'outfit', 'fashionblogger']
# >>> ['outfitoftheday', 'fashionista', 'streetstyle']
# ['fashion', 'tshirt', 'styleblogger', 'outfit', 'fashionista']
# >>> ['streetstyle', 'style', 'fashionblogger', 'outfitoftheday']
# ['happy', 'fashion', 'outfit', 'fashionblogger']
# >>> ['styleblogger', 'streetstyle', 'style']
# ['style', 'outfitoftheday', 'styleblogger', 'fashion']
# >>> ['streetstyle', 'fashionista', 'outfit']
# ['fashion', 'streetstyle', 'styleblogger', 'style']
# >>> ['fashionista', 'fashionblogger', 'outfitoftheday']
# ['fashion', 'outfit', 'fashionblogger', 'style']
# >>> ['fashionista']
# ['health', 'fitness', 'healthy', 'healthylifestyle']
# >>> ['wellness']
# ['weightlossjourney', 'wellness', 'healthylifestyle', 'nutrition', 'healthy']
# >>> ['health']
# ['nutrition', 'healthy', 'healthylifestyle', 'health']
# >>> ['wellness']
# ['comedy', 'food', 'yummy', 'instafood']
# >>> ['foodstagram', 'delicious', 'foodie', 'bonappetit', 'foodlover', 'tasty']
# ['hiphop', 'fashion', 'style', 'outfitoftheday']
# >>> ['outfit', 'fashionblogger', 'streetstyle', 'fashionista']
# ['health', 'crypto', 'fitness', 'healthylifestyle', 'nutrition']
# >>> ['wellness']
# ['food', 'tasty', 'foodporn', 'delicious', 'instafood']
# >>> ['yummy', 'foodie', 'foodlover']
# ['food', 'delicious', 'tasty', 'foodstagram', 'instafood']
# >>> ['foodlover']
# ['food', 'foodphotography', 'bonappetit', 'yummy', 'tasty']
# >>> ['instafood', 'foodlover', 'foodstagram', 'foodporn']
# ['food', 'instafood', 'tasty', 'bonappetit', 'foodlover']
# >>> ['foodstagram']
# ['food', 'foodlover', 'foodporn', 'instafood', 'foodstagram']
# >>> ['bonappetit', 'delicious', 'tasty']
# ['food', 'yummy', 'delicious']
# >>> ['foodie', 'foodstagram', 'bonappetit', 'instafood']
# ['food', 'bonappetit', 'instafood', 'foodstagram', 'foodlover']
# >>> ['foodie', 'foodphotography', 'delicious']
# ['colombia', 'food', 'foodlover', 'foodstagram']
# >>> ['delicious', 'tasty', 'yummy', 'instafood', 'foodphotography', 'bonappetit', 'foodporn', 'foodie']
# ['food', 'tasty', 'yummy', 'foodstagram']
# >>> ['foodphotography']
# ['food', 'foodporn', 'yummy']
# >>> ['foodstagram', 'foodie', 'tasty']
# ['food', 'foodporn', 'instafood', 'bonappetit', 'yummy']
# >>> ['foodphotography', 'foodstagram', 'delicious']
# ['food', 'foodlover', 'instafood', 'foodphotography', 'yummy']
# >>> ['foodporn', 'foodie', 'foodstagram', 'bonappetit', 'tasty', 'delicious']
# ['foodphotography', 'food', 'tasty', 'bonappetit', 'foodporn']
# >>> ['foodie']
# ['foodporn', 'food', 'foodphotography', 'instafood', 'foodstagram']
# >>> ['yummy']
# ['food', 'instafood', 'foodstagram', 'foodphotography', 'bonappetit']
# >>> ['tasty']
# ['delicious', 'foodstagram', 'foodie', 'tasty']
# >>> ['foodlover']
# ['food', 'yummy', 'delicious', 'foodporn']
# >>> ['bonappetit', 'foodie']
# ['foodblogger', 'foodphotography', 'bonappetit', 'instafood', 'yummy']
# >>> ['foodlover', 'foodporn', 'foodie']
# ['foodie', 'food', 'yummy', 'delicious']
# >>> ['foodstagram', 'foodlover', 'foodphotography', 'instafood', 'tasty']
# ['food', 'yummy', 'tasty', 'foodphotography', 'bonappetit']
# >>> ['instafood']
# ['food', 'delicious', 'bonappetit']
# >>> ['instafood', 'yummy', 'foodie', 'foodstagram', 'foodphotography', 'foodlover', 'tasty']
# ['food', 'instafood', 'foodie', 'foodphotography', 'foodstagram']
# >>> ['foodporn', 'yummy']
# ['food', 'tasty', 'foodporn', 'bonappetit', 'instafood']
# >>> ['foodstagram']
# ['food', 'yummy', 'foodporn', 'tasty']
# >>> ['foodie']
# ['food', 'delicious', 'foodphotography', 'foodstagram', 'foodlover']
# >>> ['foodporn', 'foodie', 'yummy', 'instafood', 'bonappetit', 'tasty']
# ['food', 'bonappetit', 'foodie', 'yummy']
# >>> ['delicious', 'foodstagram', 'tasty']
# ['foodporn', 'foodlover', 'yummy', 'delicious', 'tasty']
# >>> ['foodie', 'bonappetit', 'foodphotography']
# ['foodporn', 'foodlover', 'bonappetit']
# >>> ['instafood', 'tasty', 'food', 'delicious']
# ['foodporn', 'food', 'instafood', 'foodstagram']
# >>> ['yummy', 'foodie', 'bonappetit', 'foodphotography']
# ['foodpics', 'foodporn', 'bonappetit', 'foodphotography', 'tasty']
# >>> ['yummy', 'foodie', 'foodlover', 'instafood', 'foodstagram', 'delicious']
# ['foodporn', 'foodie', 'foodlover']
# >>> ['tasty', 'food']
# ['foodporn', 'yummy', 'food', 'foodstagram', 'foodie']
# >>> ['foodlover', 'delicious', 'bonappetit', 'foodphotography', 'tasty', 'instafood']
# ['foodporn', 'foodie', 'instafood', 'yummy', 'foodlover']
# >>> ['foodstagram', 'foodphotography', 'tasty', 'food']
# ['foodporn', 'foodlover', 'bonappetit']
# >>> ['foodphotography', 'food', 'tasty', 'yummy', 'delicious']
# ['foodporn', 'foodstagram', 'foodie', 'bonappetit']
# >>> ['instafood', 'foodlover', 'yummy', 'food']
# ['foodporn', 'food', 'instafood', 'foodie', 'delicious']
# >>> ['tasty', 'foodstagram', 'foodphotography', 'yummy', 'bonappetit']
# ['foodporn', 'instafood', 'foodie', 'bonappetit', 'tasty']
# >>> ['foodstagram', 'foodlover', 'food', 'yummy', 'delicious', 'foodphotography']
# ['foodporn', 'delicious', 'food', 'foodstagram']
# >>> ['yummy', 'foodphotography']
# ['foodporn', 'bonappetit', 'foodphotography', 'yummy', 'foodstagram']
# >>> ['foodlover', 'foodie']
# ['foodporn', 'food', 'foodie', 'bonappetit']
# >>> ['tasty', 'foodphotography', 'foodlover', 'foodstagram', 'yummy', 'delicious', 'instafood']
# ['foodporn', 'foodstagram', 'bonappetit', 'yummy']
# >>> ['foodie', 'foodlover', 'foodphotography', 'food', 'instafood', 'delicious', 'tasty']
# ['foodporn', 'bonappetit', 'food', 'instafood']
# >>> ['foodie', 'delicious', 'foodstagram']
# ['foodporn', 'yummy', 'tasty', 'foodphotography', 'foodie']
# >>> ['food', 'foodstagram', 'foodlover']
# ['foodporn', 'food', 'foodie', 'instafood']
# >>> ['bonappetit', 'foodphotography', 'delicious', 'tasty', 'foodstagram', 'yummy', 'foodlover']
# ['foodporn', 'yummy', 'tasty', 'delicious']
# >>> ['foodphotography']
# ['foodporn', 'foodlover', 'tasty', 'food', 'foodstagram']
# >>> ['yummy', 'foodphotography']
# ['foodporn', 'foodphotography', 'yummy', 'delicious', 'bonappetit']
# >>> ['foodstagram', 'food', 'foodlover', 'instafood']
# ['foodporn', 'yummy', 'foodphotography', 'food', 'instafood']
# >>> ['delicious']
# ['foodporn', 'instafood', 'tasty', 'foodlover', 'foodstagram']
# >>> ['foodie', 'foodphotography', 'food']
# ['foodporn', 'delicious', 'foodlover', 'foodphotography', 'foodie']
# >>> ['foodstagram', 'bonappetit']
# ['travel', 'friends', 'adventure', 'travelblogger', 'travelphotography']
# >>> ['wanderlust', 'vacation']
# ['vacation', 'trip', 'travelphotography', 'wanderlust', 'travel']
# >>> ['adventure', 'travelblogger']
# ['diet', 'healthy', 'healthylifestyle', 'wellness', 'health']
# >>> ['nutrition']
# ['life', 'art', 'painting', 'colors', 'artistzone']
# >>> ['color', 'drawing', 'creative']
# ['style', 'photooftheday', 'photoshoot', 'styleblogger', 'outfitoftheday']
# >>> ['fashion', 'fashionblogger']
# ['happy', 'outfitoftheday', 'outfit', 'fashionblogger', 'fashionista']
# >>> ['styleblogger', 'streetstyle', 'fashion', 'style']
# ['health', 'happy', 'healthy', 'nutrition', 'healthylifestyle']
# >>> ['wellness']
# ['fashion', 'photooftheday', 'fashionstyle', 'fashionblogger', 'streetstyle']
# >>> ['style', 'styleblogger', 'outfitoftheday', 'fashionista', 'outfit']
# ['travel', 'blogger', 'adventure', 'travelblogger']
# >>> ['wanderlust']
# ['daily', 'selflove', 'quote', 'inspiration', 'goals']
# >>> ['goodvibes']
# ['fashion', 'outfit', 'fashionista', 'style', 'outfitoftheday']
# >>> ['fashionblogger', 'styleblogger']
# ['daily', 'blog', 'selflove', 'inspiration', 'goodvibes']
# >>> ['quotes']
# ['fashion', 'outfitoftheday', 'fashionista', 'fashionblogger', 'streetstyle']
# >>> ['style', 'outfit']
# ['style', 'fashion', 'fashionblogger', 'streetstyle', 'outfitoftheday']
# >>> ['styleblogger', 'outfit']
# ['wanderlust', 'earth', 'travelphotography', 'travelblogger', 'adventure']
# >>> ['vacation']
# ['inspiration', 'quote', 'selflove', 'goals']
# >>> ['quotes']
# ['inspiration', 'handsome', 'quote', 'quotes']
# >>> ['goals']
# ['inspiration', 'mindset', 'goals', 'quote']
# >>> ['goodvibes', 'quotes']
# ['fashion', 'styleblogger', 'streetstyle', 'fashionista', 'fashionblogger']
# >>> ['outfit']
# ['travel', 'photographer', 'travelblogger', 'vacation', 'wanderlust']
# >>> ['adventure']
# ['photo', 'adventure', 'travelblogger', 'vacation']
# >>> ['travelphotography', 'wanderlust', 'travel']
# ['travel', 'travelphotography', 'tea', 'vacation', 'wanderlust']
# >>> ['travelblogger', 'adventure']
# ['healthylifestyle', 'running', 'healthy', 'nutrition', 'health']
# >>> ['wellness']
# ['photooftheday', 'adventure', 'travelblogger', 'wanderlust']
# >>> ['travelphotography', 'travel', 'vacation']
# ['homesweethome', 'selflove', 'selfcare', 'quotes', 'inspiration']
# >>> ['goals', 'quote', 'goodvibes']
# ['travel', 'blogger', 'travelblogger', 'adventure', 'vacation']
# >>> ['travelphotography', 'wanderlust']
# ['travel', 'daily', 'vacation', 'adventure', 'wanderlust']
# >>> ['travelphotography']
# ['daily', 'streetstyle', 'fashion', 'outfit']
# >>> ['styleblogger', 'fashionblogger']
# ['fashionblogger', 'streetfashion', 'fashionista', 'streetstyle']
# >>> ['styleblogger', 'outfitoftheday', 'outfit', 'fashion']
# ['goals', 'lifestyle', 'memes', 'selflove', 'goodvibes']
# >>> ['quotes']
# ['food', 'family', 'foodstagram', 'foodporn']
# >>> ['foodie', 'delicious', 'foodlover', 'instafood', 'foodphotography', 'yummy', 'bonappetit', 'tasty']
# ['style', 'streetwear', 'fashionblogger', 'fashion']
# >>> ['outfit', 'streetstyle', 'fashionista', 'outfitoftheday']
# ['nutrition', 'wellness', 'healthy', 'health']
# >>> ['healthylifestyle']
# ['fashionista', 'style', 'streetstyle', 'outfitoftheday', 'styleblogger']
# >>> ['fashion']
# ['inspiration', 'quotes', 'quote', 'selflove']
# >>> ['goals', 'goodvibes']
# ['goodvibes', 'shoes', 'quote', 'selflove', 'quotes']
# >>> ['inspiration', 'goals']
# ['cute', 'life', 'pet', 'cuteanimals', 'animaladdicts']
# >>> ['petsofourworld']
# ['lifestyle', 'healthy', 'healthylifestyle', 'health', 'nutrition']
# >>> ['wellness']
# ['lifestyle', 'art', 'colors', 'drawing']
# >>> ['artistzone', 'color', 'artwork']
# ['selflove', 'quotes', 'goals', 'quote']
# >>> ['goodvibes', 'inspiration']
# ['fashion', 'holiday', 'outfitoftheday', 'style', 'streetstyle']
# >>> ['outfit', 'styleblogger', 'fashionblogger']
# ['goodvibes', 'photooftheday', 'fashionista', 'fashion', 'quotes']
# >>> ['outfit', 'styleblogger', 'style', 'outfitoftheday', 'streetstyle', 'fashionblogger']
# ['fashion', 'selfie', 'styleblogger', 'fashionista']
# >>> ['fashionblogger', 'streetstyle', 'outfit', 'style']
# ['pet', 'cutepet', 'cutepetclub']
# >>> ['cutenessoverload', 'pets', 'cuteanimals']
# ['pet', 'animaladdicts', 'cutenessoverload', 'animals']
# >>> ['cuteanimals', 'animal', 'cutepetclub', 'cutepet', 'pets', 'petsofourworld']
# ['style', 'weddingplanner', 'streetstyle', 'styleblogger', 'outfit']
# >>> ['outfitoftheday']
# ['goals', 'quotes', 'quote']
# >>> ['goodvibes']
# ['quotes', 'motivation', 'selflove', 'goals']
# >>> ['inspiration']
# ['quotes', 'inspiration', 'goodvibes', 'quote', 'goals']
# >>> ['selflove']
# ['inspiration', 'success', 'motivation', 'goals', 'quote']
# >>> ['selflove', 'quotes', 'goodvibes']
# ['inspiration', 'motivation', 'quote', 'goals', 'goodvibes']
# >>> ['selflove']
# ['goals', 'motivation', 'quote', 'goodvibes', 'inspiration']
# >>> ['quotes']
# ['wanderlust', 'travelblogger', 'adventure', 'travelphotography', 'travel']
# >>> ['vacation']
# ['inspiration', 'nails', 'quotes', 'quote', 'selflove']
# >>> ['goodvibes']
# ['hiking', 'wanderlust', 'travelblogger', 'travel', 'adventure']
# >>> ['vacation']
# ['nature', 'pet', 'petsofourworld', 'cuteanimals', 'cutepet']
# >>> ['animal', 'cutenessoverload']
# ['travel', 'sky', 'tea', 'adventure', 'travelphotography']
# >>> ['wanderlust', 'vacation', 'travelblogger']
# ['animals', 'nature', 'pets', 'cuteanimals', 'cutenessoverload']
# >>> ['cutepet', 'animal']
# ['naturephotography', 'travel', 'photographylovers', 'wanderlust', 'adventure']
# >>> ['travelblogger']
# ['friend', 'pet', 'pets', 'cutenessoverload', 'petsofourworld']
# >>> ['cutepetclub', 'cutepet', 'animals', 'animaladdicts', 'cuteanimals', 'animal']
# ['travelphotography', 'beautiful', 'travelblogger', 'wanderlust']
# >>> ['travel']
# ['naturephotography', 'photography', 'art', 'artistzone', 'creative']
# ...
# >>> ['fashionista', 'streetstyle', 'outfit']
# ['fashion', 'couple', 'outfitoftheday', 'streetstyle', 'styleblogger']
# >>> ['style', 'fashionblogger']
# ['style', 'autumn', 'outfitoftheday', 'styleblogger']
# >>> ['streetstyle', 'outfit', 'fashion']
# ['style', 'fashionista', 'fashion', 'outfit']
# >>> ['fashionblogger', 'streetstyle', 'outfitoftheday']
# ['style', 'streetstyle', 'outfit', 'outfitoftheday', 'styleblogger']
# >>> ['fashionista']
# ['style', 'styleblogger', 'fashionblogger']
# >>> ['streetstyle', 'outfit', 'fashionista', 'outfitoftheday', 'fashion']
# ['style', 'outfit', 'fashionista', 'fashion']
# >>> ['streetstyle', 'styleblogger', 'fashionblogger']
# ['style', 'outfit', 'outfitoftheday', 'fashionblogger']
# >>> ['fashion']
# ['style', 'fashionista', 'streetstyle', 'fashion', 'fashionblogger']
# >>> ['styleblogger', 'outfit', 'outfitoftheday']
# ['style', 'fashionblogger', 'outfitoftheday', 'outfit', 'streetstyle']
# >>> ['fashionista']
# ['style', 'fashionblogger', 'styleblogger']
# >>> ['outfitoftheday']
# ['art', 'artistzone', 'drawing']
# >>> ['painting', 'artwork', 'creative', 'color']
# ['style', 'fashionista', 'fashionblogger', 'outfit']
# >>> ['styleblogger', 'outfitoftheday', 'fashion']
# ['style', 'streetstyle', 'fashionblogger', 'outfitoftheday']
# >>> ['fashionista', 'styleblogger', 'outfit']
# ['style', 'streetstyle', 'fashion', 'fashionista', 'outfitoftheday']
# >>> ['fashionblogger', 'styleblogger', 'outfit']
# ['style', 'streetstyle', 'outfit', 'fashion', 'outfitoftheday']
# >>> ['styleblogger']
# ['style', 'outfitoftheday', 'streetstyle', 'fashionista', 'fashion']
# >>> ['styleblogger', 'outfit']
# ['style', 'fashion', 'streetstyle', 'fashionblogger', 'outfitoftheday']
# >>> ['fashionista', 'styleblogger', 'outfit']
# ['style', 'fashionblogger', 'outfitoftheday']
# >>> ['fashion', 'styleblogger', 'outfit']
# ['style', 'fashionblogger', 'streetstyle', 'fashion', 'outfit']
# >>> ['outfitoftheday']
# ['style', 'outfitoftheday', 'outfit', 'streetstyle', 'fashion']
# >>> ['fashionblogger', 'styleblogger']
# ['style', 'outfitoftheday', 'fashionista', 'styleblogger']
# >>> ['fashion', 'fashionblogger']
# ['style', 'outfitoftheday', 'streetstyle', 'fashion']
# >>> ['styleblogger', 'fashionista', 'outfit', 'fashionblogger']
# ['style', 'fashionista', 'outfitoftheday', 'styleblogger', 'streetstyle']
# >>> ['fashion']
# ['style', 'fashion', 'outfit', 'fashionblogger', 'streetstyle']
# >>> ['fashionista']
# ['style', 'streetstyle', 'fashion', 'outfitoftheday']
# >>> ['outfit', 'fashionista']
# ['style', 'fashion', 'styleblogger', 'fashionista']
# >>> ['outfitoftheday']
# ['style', 'styleblogger', 'outfitoftheday']
# >>> ['fashionista', 'outfit', 'fashionblogger']
# ['style', 'fashion', 'styleblogger', 'fashionista']
# >>> ['fashionblogger']
# ['style', 'styleblogger', 'fashionista', 'fashion']
# >>> ['fashionblogger', 'outfit']
# ['style', 'outfit', 'fashion', 'streetstyle', 'fashionblogger']
# >>> ['outfitoftheday', 'styleblogger']
# ['style', 'outfit', 'outfitoftheday', 'fashion']
# >>> ['fashionista', 'styleblogger', 'fashionblogger', 'streetstyle']
# ['style', 'fashionblogger', 'streetstyle', 'outfit']
# >>> ['outfitoftheday', 'styleblogger', 'fashionista']
# ['style', 'styleblogger', 'fashionista', 'streetstyle']
# >>> ['outfit']
# ['style', 'outfitoftheday', 'fashionblogger']
# >>> ['styleblogger']
# ['style', 'fashion', 'outfitoftheday', 'styleblogger', 'fashionblogger']
# >>> ['streetstyle', 'outfit', 'fashionista']
# ['style', 'outfit', 'fashion', 'fashionblogger', 'streetstyle']
# >>> ['outfitoftheday', 'fashionista', 'styleblogger']
# ['style', 'outfit', 'outfitoftheday', 'fashionblogger']
# >>> ['fashionista', 'streetstyle']
# ['style', 'outfitoftheday', 'fashion', 'outfit']
# >>> ['fashionista', 'streetstyle']
# ['style', 'outfit', 'outfitoftheday', 'fashionista']
# >>> ['fashionblogger', 'fashion', 'styleblogger']
# ['style', 'outfitoftheday', 'outfit', 'styleblogger', 'fashion']
# >>> ['streetstyle']
# ['style', 'outfit', 'fashionblogger', 'outfitoftheday']
# >>> ['streetstyle', 'styleblogger', 'fashion']
# ['style', 'fashion', 'fashionista', 'outfit']
# >>> ['outfitoftheday', 'streetstyle', 'styleblogger', 'fashionblogger']
# ['style', 'fashionista', 'streetstyle']
# >>> ['outfitoftheday', 'fashionblogger']
# ['style', 'fashionblogger', 'fashion', 'styleblogger', 'outfitoftheday']
# >>> ['outfit']
# ['style', 'fashion', 'fashionblogger', 'outfit', 'styleblogger']
# >>> ['fashionista']
# ['style', 'outfit', 'styleblogger', 'fashionista', 'fashionblogger']
# >>> ['streetstyle']
# ['style', 'fashionblogger', 'fashion', 'outfit']
# >>> ['streetstyle']
# ['style', 'fashionblogger', 'streetstyle', 'outfit', 'styleblogger']
# >>> ['outfitoftheday', 'fashion']
# ['style', 'fashionista', 'streetstyle', 'fashionblogger', 'outfit']
# >>> ['styleblogger']
# ['style', 'styleblogger', 'outfitoftheday', 'fashionista']
# >>> ['fashion', 'streetstyle', 'fashionblogger', 'outfit']
# ['style', 'fashionblogger', 'fashionista', 'streetstyle', 'outfit']
# >>> ['styleblogger', 'outfitoftheday', 'fashion']
# ['style', 'fashionblogger', 'outfitoftheday', 'fashion']
# >>> ['fashionista']
# ['style', 'fashionista', 'fashion', 'outfit', 'outfitoftheday']
# >>> ['fashionblogger', 'streetstyle', 'styleblogger']
# ['style', 'fashion', 'fashionblogger', 'streetstyle']
# >>> ['outfitoftheday', 'outfit']
# ['style', 'fashionblogger', 'fashion', 'fashionista', 'streetstyle']
# >>> ['outfitoftheday', 'styleblogger']
# ['style', 'outfit', 'styleblogger', 'outfitoftheday', 'streetstyle']
# >>> ['fashion', 'fashionblogger']
# ['style', 'fashionblogger', 'outfit', 'outfitoftheday', 'streetstyle']
# >>> ['fashion', 'styleblogger']
# ['style', 'streetstyle', 'fashion', 'fashionista']
# >>> ['outfitoftheday', 'styleblogger']
# ['travel', 'ocean', 'summer', 'travelblogger', 'adventure']
# >>> ['vacation', 'wanderlust']
# ['nature', 'adventure', 'vacation', 'wanderlust']
# >>> ['travelblogger', 'travel', 'travelphotography']
# ['travel', 'vacation', 'adventure', 'travelphotography', 'travelblogger']
# >>> ['wanderlust']
# ['travel', 'travelblogger', 'vacation']
# >>> ['adventure', 'travelphotography', 'wanderlust']
# ['travel', 'vacation', 'travelblogger', 'wanderlust', 'travelphotography']
# >>> ['adventure']
# ['travel', 'adventure', 'vacation', 'travelphotography', 'wanderlust']
# >>> ['travelblogger']
# ['travel', 'travelphotography', 'wanderlust', 'vacation', 'travelblogger']
# >>> ['adventure']
# ['travel', 'travelphotography', 'travelblogger', 'wanderlust']
# >>> ['adventure']
# ['travel', 'travelphotography', 'vacation', 'adventure', 'travelblogger']
# >>> ['wanderlust']
# ['travel', 'wanderlust', 'vacation', 'travelphotography', 'adventure']
# >>> ['travelblogger']
# ['travel', 'adventure', 'travelphotography', 'travelblogger']
# >>> ['wanderlust', 'vacation']
# ['travel', 'vacation', 'travelphotography', 'travelblogger', 'wanderlust']
# >>> ['adventure']
# ['travel', 'vacation', 'travelphotography', 'adventure']
# >>> ['travelblogger']
# ['travel', 'travelblogger', 'travelphotography', 'adventure', 'wanderlust']
# >>> ['vacation']
# ['travel', 'vacation', 'adventure', 'travelphotography', 'travelblogger']
# >>> ['wanderlust']
# ['travel', 'adventure', 'vacation', 'travelblogger', 'travelphotography']
# >>> ['wanderlust']
# ['travel', 'photo', 'wanderlust', 'vacation', 'adventure']
# >>> ['travelphotography']
# ['travel', 'travelblogger', 'vacation', 'adventure', 'wanderlust']
# >>> ['travelphotography']
# ['travel', 'vacation', 'wanderlust']
# >>> ['travelblogger', 'adventure']
# ['travel', 'travelblogger', 'wanderlust', 'adventure']
# >>> ['vacation', 'travelphotography']
# ['travel', 'adventure', 'travelphotography', 'vacation']
# >>> ['travelblogger', 'wanderlust']
# ['travel', 'adventure', 'travelblogger']
# >>> ['vacation', 'travelphotography', 'wanderlust']
# ['travel', 'travelblogger', 'wanderlust', 'adventure']
# >>> ['vacation', 'travelphotography']
# ['travel', 'adventure', 'wanderlust', 'travelblogger']
# >>> ['vacation']
# ['travel', 'adventure', 'vacation', 'travelphotography', 'travelblogger']
# >>> ['wanderlust']
# ['travel', 'travelphotography', 'wanderlust']
# >>> ['vacation']
# ['travel', 'travelphotography', 'travelblogger', 'adventure', 'vacation']
# >>> ['wanderlust']
# ['travel', 'vacation', 'travelphotography']
# >>> ['wanderlust', 'adventure', 'travelblogger']
# ['travel', 'vacation', 'wanderlust', 'travelblogger', 'travelphotography']
# >>> ['adventure']
# ['travel', 'adventure', 'travelblogger', 'vacation', 'wanderlust']
# >>> ['travelphotography']
# ['snow', 'wanderlust', 'travelphotography', 'travel', 'adventure']
# >>> ['vacation', 'travelblogger']
# ['travel', 'beautiful', 'travelblogger', 'travelphotography', 'adventure']
# >>> ['wanderlust', 'vacation']
# ['travel', 'wanderlust', 'travelblogger', 'vacation', 'adventure']
# >>> ['travelphotography']
# ['travel', 'travelphotography', 'adventure']
# >>> ['travelblogger']
# ['travel', 'travelphotography', 'wanderlust', 'vacation', 'adventure']
# >>> ['travelblogger']
# ['travel', 'travelphotography', 'adventure', 'wanderlust']
# >>> ['vacation']
# ['travel', 'travelphotography', 'vacation', 'adventure']
# >>> ['travelblogger', 'wanderlust']
# ['travel', 'wanderlust', 'travelphotography', 'travelblogger', 'adventure']
# >>> ['vacation']
# ['travel', 'wanderlust', 'vacation', 'travelphotography', 'adventure']
# >>> ['travelblogger']
# ['photography', 'travel', 'flowerphotography', 'adventure', 'wanderlust']
# >>> ['vacation']
# ['travel', 'vacation', 'travelblogger']
# >>> ['wanderlust', 'travelphotography']
# ['travel', 'adventure', 'vacation', 'wanderlust']
# >>> ['travelblogger']
# ['travel', 'travelblogger', 'travelphotography']
# >>> ['wanderlust']
# ['travel', 'vacation', 'travelblogger', 'adventure', 'wanderlust']
# >>> ['travelphotography']
# ['travel', 'vacation', 'wanderlust', 'adventure']
# >>> ['travelblogger']
# ['travel', 'travelblogger', 'vacation', 'travelphotography']
# >>> ['wanderlust', 'adventure']
# ['travel', 'nature', 'wanderlust', 'vacation']
# >>> ['adventure', 'travelphotography', 'travelblogger']
# ['travel', 'travelblogger', 'travelphotography', 'wanderlust', 'adventure']
# >>> ['vacation']
# ['travel', 'travelblogger', 'vacation', 'adventure', 'travelphotography']
# >>> ['wanderlust']
# ['travel', 'adventure', 'vacation']
# >>> ['wanderlust', 'travelphotography']
# ['travel', 'adventure', 'wanderlust', 'travelblogger']
# >>> ['travelphotography']
# ['travel', 'travelphotography', 'vacation', 'adventure', 'wanderlust']
# >>> ['travelblogger']
# ['travel', 'travelblogger', 'wanderlust']
# >>> ['travelphotography', 'vacation', 'adventure']
# ['travel', 'travelphotography', 'adventure', 'wanderlust', 'vacation']
# >>> ['travelblogger']
# ['travel', 'travelphotography', 'travelblogger', 'vacation', 'wanderlust']
# >>> ['adventure']
# ['travel', 'and', 'adventure', 'wanderlust', 'travelphotography']
# >>> ['travelblogger', 'vacation']
# ['travel', 'vacation', 'travelblogger', 'travelphotography', 'adventure']
# >>> ['wanderlust']
# ['travel', 'vacation', 'travelblogger', 'wanderlust']
# >>> ['travelphotography', 'adventure']
# ['travel', 'vacation', 'travelblogger', 'travelphotography', 'wanderlust']
# >>> ['adventure']
# ['travel', 'travelphotography', 'travelblogger', 'vacation', 'adventure']
# >>> ['wanderlust']
# ['travel', 'wanderlust', 'travelphotography', 'adventure']
# >>> ['travelblogger', 'vacation']
# ['travel', 'adventure', 'travelphotography', 'vacation', 'travelblogger']
# >>> ['wanderlust']
# ['travel', 'travelphotography', 'wanderlust', 'vacation', 'travelblogger']
# >>> ['adventure']
# ['travel', 'vacation', 'adventure', 'wanderlust', 'travelphotography']
# >>> ['travelblogger']
# ['fashionblogger', 'travel', 'traveltheworld', 'vacation', 'wanderlust']
# >>> ['streetstyle', 'fashionista', 'outfitoftheday', 'styleblogger', 'style']
# ['travel', 'travelphotography', 'vacation', 'travelblogger', 'adventure']
# >>> ['wanderlust']
# ['travel', 'adventure', 'travelphotography', 'travelblogger', 'wanderlust']
# >>> ['vacation']
# ['travel', 'travelblogger', 'wanderlust', 'vacation', 'travelphotography']
# >>> ['adventure']
# ['travel', 'vacation', 'wanderlust', 'adventure', 'travelblogger']
# >>> ['travelphotography']
# ['travel', 'travelblogger', 'adventure', 'wanderlust']
# >>> ['vacation']
# ['travel', 'vacation', 'adventure', 'travelphotography']
# >>> ['travelblogger']
# ['travel', 'world', 'beautiful', 'travelphotography', 'adventure']
# >>> ['wanderlust', 'vacation']
# ['travel', 'vacation', 'travelblogger', 'travelphotography', 'wanderlust']
# >>> ['adventure']
# ['travel', 'vacation', 'adventure', 'wanderlust', 'travelphotography']
# >>> ['travelblogger']
# ['travel', 'wanderlust', 'travelblogger', 'travelphotography', 'adventure']
# >>> ['vacation']
# ['travel', 'travelblogger', 'vacation', 'adventure', 'wanderlust']
# >>> ['travelphotography']
# ['travel', 'urban', 'adventure', 'vacation', 'travelblogger']
# >>> ['wanderlust', 'travelphotography']
# ['travel', 'adventure', 'travelphotography', 'wanderlust', 'vacation']
# >>> ['travelblogger']
# ['travel', 'travelphotography', 'travelblogger', 'adventure']
# >>> ['wanderlust', 'vacation']
# ['hotel', 'travel', 'vacation', 'adventure', 'travelblogger']
# >>> ['travelphotography']
# ['travel', 'travelphotography', 'vacation', 'travelblogger', 'adventure']
# >>> ['wanderlust']
# ['travel', 'travelphotography', 'wanderlust', 'vacation', 'adventure']
# >>> ['travelblogger']
# ['travel', 'vacation', 'travelphotography', 'adventure', 'wanderlust']
# >>> ['travelblogger']
# ['travel', 'history', 'wanderlust', 'vacation', 'travelphotography']
# >>> ['adventure']
# ['travel', 'wanderlust', 'travelphotography', 'vacation', 'adventure']
# >>> ['travelblogger']
# ['travel', 'wanderlust', 'adventure', 'travelblogger']
# >>> ['travelphotography']
# ['travel', 'wanderlust', 'adventure', 'vacation', 'travelphotography']
# >>> ['travelblogger']
# ['travel', 'holiday', 'adventure', 'vacation', 'wanderlust']
# >>> ['travelphotography', 'travelblogger']
# ['travel', 'vacation', 'wanderlust', 'adventure']
# >>> ['travelphotography']
# ['travel', 'wanderlust', 'travelphotography', 'travelblogger']
# >>> ['vacation']
# ['travel', 'adventure', 'vacation', 'travelblogger', 'wanderlust']
# >>> ['travelphotography']
# ['mountain', 'travel', 'weekendvibes', 'wanderlust', 'adventure']
# >>> ['travelphotography', 'vacation']
# ['travel', 'vacation', 'travelphotography', 'wanderlust', 'adventure']
# >>> ['travelblogger']
# ['travel', 'travelblogger', 'wanderlust', 'travelphotography']
# >>> ['adventure', 'vacation']
# ['travel', 'adventure', 'wanderlust', 'travelblogger', 'vacation']
# >>> ['travelphotography']
# ['travel', 'travelphotography', 'travelblogger', 'vacation']
# >>> ['adventure', 'wanderlust']
# ['travel', 'adventure', 'travelblogger', 'vacation']
# >>> ['wanderlust']
# ['travel', 'adventure', 'travelphotography']
# >>> ['vacation']
# ['travel', 'blogger', 'travelblogger', 'travelphotography']
# >>> ['wanderlust']
# ['design', 'fashion', 'streetstyle', 'outfitoftheday', 'style']
# >>> ['fashionblogger', 'styleblogger', 'fashionista', 'outfit']
# ['bridal', 'art', 'drawing', 'creative']
# >>> ['painting', 'color', 'artistzone', 'artwork']
# ['fashion', 'wedding', 'style', 'outfit']
# >>> ['streetstyle', 'styleblogger', 'fashionista', 'fashionblogger', 'outfitoftheday']
# ['fashionblogger', 'holiday', 'style', 'styleblogger', 'fashion']
# >>> ['streetstyle']
# ['fashion', 'fashionblogger', 'fashionista']
# >>> ['outfit', 'style']
# ['fashionblogger', 'glam', 'influencer', 'fashionista', 'streetstyle']
# >>> ['outfitoftheday', 'styleblogger']
# ['style', 'outfit', 'fashion', 'fashionblogger', 'fashionista']
# >>> ['streetstyle']
# ['goodvibes', 'summer', 'inspiration', 'selflove']
# >>> ['quotes', 'quote']
# ['health', 'healthy', 'nutrition', 'healthylifestyle']
# >>> ['wellness']
# ['healthylifestyle', 'selflove', 'goals', 'healthy', 'health']
# >>> ['quotes', 'goodvibes']
# ['goals', 'goodvibes', 'selflove', 'quote', 'quotes']
# >>> ['inspiration']
# ['wellness', 'selfcare', 'nutrition', 'healthy']
# >>> ['healthylifestyle', 'health']
# ['nutrition', 'yoga', 'healthylifestyle', 'health', 'wellness']
# >>> ['healthy']
# ['photography', 'travel', 'travelblogger', 'travelphotography', 'vacation']
# >>> ['adventure', 'wanderlust']
# ['health', 'workout', 'healthy', 'wellness']
# >>> ['healthylifestyle']
# ['fashion', 'fitnessmotivation', 'outfitoftheday', 'outfit']
# >>> ['fashionblogger']

# %%
with open('fuller_hashtags.txt', 'w', encoding='utf-8') as file:
    for row in additional_data:
        file.write(' '.join(row)+'\n')
